# %%
#Import the necessary libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as  plt 
# import plotly.offline as pyo
# pyo.init_notebook_mode()
# import plotly.express as px
# %matplotlib inline

# %%
#Import the dataset into a dataframe
df = pd.read_csv (r'C:\Users\user\Desktop\test\moviestreams.csv')
df.head()
# Out:
#    Unnamed: 0  ID                           Title  Year  Age  IMDb  \
# 0           0   1                       Inception  2010  13+   8.8
# 1           1   2                      The Matrix  1999  18+   8.7
# 2           2   3          Avengers: Infinity War  2018  13+   8.5
# 3           3   4              Back to the Future  1985   7+   8.5
# 4           4   5  The Good, the Bad and the Ugly  1966  18+   8.8
#
#   Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0             87%        1     0            0        0     0
# 1             87%        1     0            0        0     0
# 2             84%        1     0            0        0     0
# 3             96%        1     0            0        0     0
# 4             97%        1     0            1        0     0
#
#                         Directors                            Genres  \
# 0               Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# ...

# %%
#check the number of rows and  columns of the dataset
df.shape
# Out:
# (16744, 17)

# %%
#show number of dimensions of the df
df.ndim
# Out:
# 2

# %%
#count the number of elements in the dataset
df.size
# Out:
# 284648

# %%
#show columns names
cols = df.columns.tolist()
cols
# Out:
# ['Unnamed: 0',
#  'ID',
#  'Title',
#  'Year',
#  'Age',
#  'IMDb',
#  'Rotten Tomatoes',
#  'Netflix',
#  'Hulu',
#  'Prime Video',
#  'Disney+',
#  'Type',
#  'Directors',
#  'Genres',
#  'Country',
#  'Language',
#  'Runtime']

# %%
df.describe() # statistical description
# Out:
#          Unnamed: 0            ID          Year          IMDb       Netflix  \
# count  16744.000000  16744.000000  16744.000000  16173.000000  16744.000000
# mean    8371.500000   8372.500000   2003.014035      5.902751      0.212613
# std     4833.720789   4833.720789     20.674321      1.347867      0.409169
# min        0.000000      1.000000   1902.000000      0.000000      0.000000
# 25%     4185.750000   4186.750000   2000.000000      5.100000      0.000000
# 50%     8371.500000   8372.500000   2012.000000      6.100000      0.000000
# 75%    12557.250000  12558.250000   2016.000000      6.900000      0.000000
# max    16743.000000  16744.000000   2020.000000      9.300000      1.000000
#
#                Hulu   Prime Video       Disney+     Type       Runtime
# count  16744.000000  16744.000000  16744.000000  16744.0  16152.000000
# mean       0.053930      0.737817      0.033684      0.0     93.413447
# std        0.225886      0.439835      0.180419      0.0     28.219222
# ...

# %% [markdown]
# # Data manipulation

# %%
#drop no needed columns 
df.drop(['Unnamed: 0','ID'],axis = 1, inplace=True )
df.head()
# Out:
#                             Title  Year  Age  IMDb Rotten Tomatoes  Netflix  \
# 0                       Inception  2010  13+   8.8             87%        1
# 1                      The Matrix  1999  18+   8.7             87%        1
# 2          Avengers: Infinity War  2018  13+   8.5             84%        1
# 3              Back to the Future  1985   7+   8.5             96%        1
# 4  The Good, the Bad and the Ugly  1966  18+   8.8             97%        1
#
#    Hulu  Prime Video  Disney+  Type                       Directors  \
# 0     0            0        0     0               Christopher Nolan
# 1     0            0        0     0  Lana Wachowski,Lilly Wachowski
# 2     0            0        0     0         Anthony Russo,Joe Russo
# 3     0            0        0     0                 Robert Zemeckis
# 4     0            1        0     0                    Sergio Leone
#
#                              Genres                       Country  \
# ...

# %%
df.describe() # statistical description
# Out:
#                Year          IMDb       Netflix          Hulu   Prime Video  \
# count  16744.000000  16173.000000  16744.000000  16744.000000  16744.000000
# mean    2003.014035      5.902751      0.212613      0.053930      0.737817
# std       20.674321      1.347867      0.409169      0.225886      0.439835
# min     1902.000000      0.000000      0.000000      0.000000      0.000000
# 25%     2000.000000      5.100000      0.000000      0.000000      0.000000
# 50%     2012.000000      6.100000      0.000000      0.000000      1.000000
# 75%     2016.000000      6.900000      0.000000      0.000000      1.000000
# max     2020.000000      9.300000      1.000000      1.000000      1.000000
#
#             Disney+     Type       Runtime
# count  16744.000000  16744.0  16152.000000
# mean       0.033684      0.0     93.413447
# std        0.180419      0.0     28.219222
# min        0.000000      0.0      1.000000
# 25%        0.000000      0.0     82.000000
# ...

# %%
#show duplicated rows
df[df.duplicated()]

#NO duplicated rows
# Out:
# Empty DataFrame
# Columns: [Title, Year, Age, IMDb, Rotten Tomatoes, Netflix, Hulu, Prime Video, Disney+, Type, Directors, Genres, Country, Language, Runtime]
# Index: []

# %%
#count non null values and show column type
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16744 entries, 0 to 16743
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Title            16744 non-null  object
#  1   Year             16744 non-null  int64
#  2   Age              7354 non-null   object
#  3   IMDb             16173 non-null  float64
#  4   Rotten Tomatoes  5158 non-null   object
#  5   Netflix          16744 non-null  int64
#  6   Hulu             16744 non-null  int64
#  7   Prime Video      16744 non-null  int64
#  8   Disney+          16744 non-null  int64
#  9   Type             16744 non-null  int64
#  10  Directors        16018 non-null  object
#  11  Genres           16469 non-null  object
#  12  Country          16309 non-null  object
#  13  Language         16145 non-null  object
#  14  Runtime          16152 non-null  float64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 1.9+ MB

# %%
#count null values per columns
df.isnull().sum()
# Out:
# Title                  0
# Year                   0
# Age                 9390
# IMDb                 571
# Rotten Tomatoes    11586
# Netflix                0
# Hulu                   0
# Prime Video            0
# Disney+                0
# Type                   0
# Directors            726
# Genres               275
# Country              435
# Language             599
# Runtime              592
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
#change data type of 'age' column

df['Age'].head()
# Out:
# 0    13+
# 1    18+
# 2    13+
# 3     7+
# 4    18+
# Name: Age, dtype: object

# %%
df.Age.value_counts().plot.bar() #visualise the number of movies per category
# Out:
# <AxesSubplot:>

# %%
df['Age'].unique()
# Out:
# array(['13+', '18+', '7+', nan, 'all', '16+'], dtype=object)

# %%
Age_mapp = {'13+':13,'18+':18,'7+':7,'16+':16,'All':0}

df['NewAge']=df['Age'].map(Age_mapp)
df.head()
# Out:
#                             Title  Year  Age  IMDb Rotten Tomatoes  Netflix  \
# 0                       Inception  2010  13+   8.8             87%        1
# 1                      The Matrix  1999  18+   8.7             87%        1
# 2          Avengers: Infinity War  2018  13+   8.5             84%        1
# 3              Back to the Future  1985   7+   8.5             96%        1
# 4  The Good, the Bad and the Ugly  1966  18+   8.8             97%        1
#
#    Hulu  Prime Video  Disney+  Type                       Directors  \
# 0     0            0        0     0               Christopher Nolan
# 1     0            0        0     0  Lana Wachowski,Lilly Wachowski
# 2     0            0        0     0         Anthony Russo,Joe Russo
# 3     0            0        0     0                 Robert Zemeckis
# 4     0            1        0     0                    Sergio Leone
#
#                              Genres                       Country  \
# ...

# %%
#change data type of 'Rotten Tomatoes' column in onther way

df['Rotten Tomatoes'].head()
# Out:
# 0    87%
# 1    87%
# 2    84%
# 3    96%
# 4    97%
# Name: Rotten Tomatoes, dtype: object

# %%
df['Rotten Tomatoes'].unique()
# Out:
# array(['87%', '84%', '96%', '97%', '95%', '89%', '100%', '93%', '88%',
#        '91%', '86%', '92%', '90%', '94%', '80%', '81%', '77%', '85%',
#        '79%', '67%', '83%', '75%', '98%', '65%', '71%', '82%', '99%',
#        '68%', '73%', '66%', '78%', '63%', '76%', '74%', '55%', '70%',
#        '61%', '69%', '40%', '43%', '72%', '60%', '39%', '62%', '31%',
#        '64%', '59%', '35%', '52%', '46%', '48%', '49%', '56%', '57%',
#        '41%', '53%', '23%', '28%', '50%', '36%', nan, '33%', '54%', '58%',
#        '17%', '27%', '42%', '38%', '30%', '45%', '47%', '26%', '29%',
#        '24%', '20%', '44%', '51%', '34%', '19%', '37%', '32%', '22%',
#        '16%', '11%', '25%', '13%', '15%', '12%', '18%', '8%', '9%', '14%',
#        '6%', '21%', '5%', '10%', '4%', '7%', '3%', '2%'], dtype=object)

# %%
df['Rot_Toma']=df['Rotten Tomatoes'].str.replace('%','')
df.head()
# Out:
#                             Title  Year  Age  IMDb Rotten Tomatoes  Netflix  \
# 0                       Inception  2010  13+   8.8             87%        1
# 1                      The Matrix  1999  18+   8.7             87%        1
# 2          Avengers: Infinity War  2018  13+   8.5             84%        1
# 3              Back to the Future  1985   7+   8.5             96%        1
# 4  The Good, the Bad and the Ugly  1966  18+   8.8             97%        1
#
#    Hulu  Prime Video  Disney+  Type                       Directors  \
# 0     0            0        0     0               Christopher Nolan
# 1     0            0        0     0  Lana Wachowski,Lilly Wachowski
# 2     0            0        0     0         Anthony Russo,Joe Russo
# 3     0            0        0     0                 Robert Zemeckis
# 4     0            1        0     0                    Sergio Leone
#
#                              Genres                       Country  \
# ...

# %%
df['Rot_Toma'].dtype ##Still object
# Out:
# dtype('O')

# %%
df['Rot_Toma'] = df['Rot_Toma'].astype(float)

# %%
df['Rot_Toma'].head()
# Out:
# 0    87.0
# 1    87.0
# 2    84.0
# 3    96.0
# 4    97.0
# Name: Rot_Toma, dtype: float64

# %%
df['Rot_Toma'].unique()
# Out:
# array([ 87.,  84.,  96.,  97.,  95.,  89., 100.,  93.,  88.,  91.,  86.,
#         92.,  90.,  94.,  80.,  81.,  77.,  85.,  79.,  67.,  83.,  75.,
#         98.,  65.,  71.,  82.,  99.,  68.,  73.,  66.,  78.,  63.,  76.,
#         74.,  55.,  70.,  61.,  69.,  40.,  43.,  72.,  60.,  39.,  62.,
#         31.,  64.,  59.,  35.,  52.,  46.,  48.,  49.,  56.,  57.,  41.,
#         53.,  23.,  28.,  50.,  36.,  nan,  33.,  54.,  58.,  17.,  27.,
#         42.,  38.,  30.,  45.,  47.,  26.,  29.,  24.,  20.,  44.,  51.,
#         34.,  19.,  37.,  32.,  22.,  16.,  11.,  25.,  13.,  15.,  12.,
#         18.,   8.,   9.,  14.,   6.,  21.,   5.,  10.,   4.,   7.,   3.,
#          2.])

# %% [markdown]
# # Data Quering for comprehension

# %%
#Show the number of movies for each age category
df['Age'].value_counts()
# Out:
# 18+    3474
# 7+     1462
# 13+    1255
# all     843
# 16+     320
# Name: Age, dtype: int64

# %%
 #visualise the number of movies per category

df['Age'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
#show the top 10 languages:

# %%
df['Language'].head(10)

#PB : Some values contain multiple languages
# Out:
# 0                        English,Japanese,French
# 1                                        English
# 2                                        English
# 3                                        English
# 4                                        Italian
# 5                                English,Spanish
# 6                         English,German,Russian
# 7                  English,German,French,Italian
# 8    English,German,Hebrew,Spanish,Arabic,Nepali
# 9                  English,German,French,Italian
# Name: Language, dtype: object

# %%
Languages =  df['Language'].value_counts().head(10)
plt.figure(figsize=(10,8))
plt.title('Top 10 Languages in streaming services')
sns.barplot(x=Languages.index,y=Languages.values)
# Out:
# <AxesSubplot:title={'center':'Top 10 Languages in streaming services'}>

# %%
#solution for multiple  languages

L3 = df['Language'].to_list()
L3
#L30 =  = [char for entry in L3 for char in entry]
# Out:
# ['English,Japanese,French',
#  'English',
#  'English',
#  'English',
#  'Italian',
#  'English,Spanish',
#  'English,German,Russian',
#  'English,German,French,Italian',
#  'English,German,Hebrew,Spanish,Arabic,Nepali',
#  'English,German,French,Italian',
#  'English,Spanish',
#  'Hindi,English',
#  'Spanish',
#  'English',
#  'English,French,Latin',
#  'Italian,English,Spanish',
#  'English,German,Greek,Arabic',
#  'English,French,Italian',
#  'English',
#  'English',
#  'English,American Sign Language',
#  'English,French',
#  'English,Japanese',
#  'English',
#  'English,Latin',
#  'English',
#  'English',
#  'English,Nyanja,Afrikaans,Zulu,Xhosa,Southern Sotho',
#  'English,Italian,Latin,Spanish,German',
#  'English,Spanish',
#  'English,Spanish',
#  'English,Spanish',
#  'Korean,Hawaiian',
#  'English',
#  'Hindi',
#  'English,Saami',
#  'English,Swedish',
#  'English',
#  'Hindi,English',
#  'English,German',
#  'English',
#  'English',
#  'English',
# ...

# %%
flattened = [char for entry in L3 for char in str(entry).split(',')]

# %%
from collections import Counter

D3 = Counter(flattened)
D3
# Out:
# Counter({'English': 13233,
#          'Japanese': 317,
#          'French': 799,
#          'Italian': 440,
#          'Spanish': 872,
#          'German': 483,
#          'Russian': 222,
#          'Hebrew': 86,
#          'Arabic': 190,
#          'Nepali': 6,
#          'Hindi': 731,
#          'Latin': 63,
#          'Greek': 33,
#          'American Sign Language': 17,
#          'Nyanja': 2,
#          'Afrikaans': 26,
#          'Zulu': 6,
#          'Xhosa': 8,
#          'Southern Sotho': 2,
#          'Korean': 176,
#          'Hawaiian': 7,
#          'Saami': 3,
#          'Swedish': 82,
#          'Cantonese': 175,
#          'Mandarin': 352,
#          'Sinhalese': 7,
#          'Portuguese': 108,
#          'Japanese Sign Language': 2,
#          'Irish': 11,
#          'Awadhi': 4,
#          'Urdu': 58,
#          'Telugu': 112,
#          'Tamil': 150,
#          'Lingala': 6,
#          'Persian': 23,
#          'Kurdish': 4,
#          'Bengali': 46,
# ...

# %%
#D3.pop("nan")

sorted(D3, key=D3.get, reverse=True)[:10]
# Out:
# ['English',
#  'Spanish',
#  'French',
#  'Hindi',
#  'nan',
#  'German',
#  'Italian',
#  'Mandarin',
#  'Japanese',
#  'Russian']

# %%
import operator
dic = dict(sorted(D3.items(), key=operator.itemgetter(1), reverse=True)[:10])
dic
# Out:
# {'English': 13233,
#  'Spanish': 872,
#  'French': 799,
#  'Hindi': 731,
#  'nan': 599,
#  'German': 483,
#  'Italian': 440,
#  'Mandarin': 352,
#  'Japanese': 317,
#  'Russian': 222}

# %%
plt.figure(figsize=(10,8))
plt.title('Top 10 languages in Streaming services')
sns.barplot(x=list(dic.keys()),y=list(dic.values()))
# Out:
# <AxesSubplot:title={'center':'Top 10 languages in Streaming services'}>

# %%
#Show results in a pie chart
fig = plt.figure(figsize =(10,8))
plt.pie(list(dic.values()), labels = list(dic.keys()))

plt.show()

# %%
#Count the numberr of movies in specific age category in all streamong services 

plt.figure(figsize=(10,8))
plt.title('The number of movies in specific age category in all streaming services')
chart  = sns.barplot(df['Age'].value_counts().index,y=df['Age'].value_counts())
chart.bar_label(chart.containers[0])
plt.show()
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Count the numberr of movies in specific age category in Netflix

netflix_df = df[df['Netflix'] == 1 ]
plt.figure(figsize=(10,8))
plt.title('The number of movies in specific age category in Netflix')
chart  = sns.barplot(netflix_df['Age'].value_counts().index,y=netflix_df['Age'].value_counts())
chart.bar_label(chart.containers[0])
plt.show()
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Count the numberr of movies in specific age category in Amazon prime

prime_df= df[df['Prime Video'] == 1 ]
plt.figure(figsize=(10,8))
plt.title('The number of movies in specific age category in Amazon prime')
chart  = sns.barplot(prime_df['Age'].value_counts().index,y=prime_df['Age'].value_counts())
chart.bar_label(chart.containers[0])
plt.show()
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Count the numberr of movies in specific age category in Hulu

hulu_df = df[df['Hulu'] == 1 ]
plt.figure(figsize=(10,8))
plt.title('The number of movies in specific age category in Hulu')
chart  = sns.barplot(hulu_df['Age'].value_counts().index,y=hulu_df['Age'].value_counts())
chart.bar_label(chart.containers[0])
plt.show()
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Count the numberr of movies in specific age category in Disney+

disney_df = df[df['Disney+'] == 1 ]
plt.figure(figsize=(10,8))
plt.title('The number of movies in specific age category in Disney+')
chart  = sns.barplot(disney_df['Age'].value_counts().index,y=disney_df['Age'].value_counts())
chart.bar_label(chart.containers[0])
plt.show()
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Rotten Tomato rating for all services

plt.figure(figsize=(35,15))
plt.title('Rotten Tomato rating for all services')
chart  = sns.barplot(df['Rotten Tomatoes'].value_counts().index,y=df['Rotten Tomatoes'].value_counts())
chart.bar_label(chart.containers[0])
plt.show()
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Number of Rotten Tomato 100% rated movies for each service
rt_rates = pd.DataFrame({'Streaming Services' :['Prime Video', 'Netflix', 'Hulu', 'Disney+'],
 'Rotten Tomato Score':[prime_df['Rotten Tomatoes'].value_counts()[0],
                        netflix_df['Rotten Tomatoes'].value_counts()[0],
                        hulu_df['Rotten Tomatoes'].value_counts()[0],
                        disney_df['Rotten Tomatoes'].value_counts()[0]]})

sorted_rt_rates=rt_rates.sort_values(ascending=False,by='Rotten Tomato Score')
plt.figure(figsize=(10,8))
plt.title('The number of Rotten Tomato 100% rated movies for each service')
chart  = sns.barplot(x=sorted_rt_rates['Streaming Services'],
                     y=sorted_rt_rates['Rotten Tomato Score'])
chart.bar_label(chart.containers[0])
plt.show()

# %%
#Number of IMDB rated movies for each service
plt.figure(figsize=(35,15))
plt.title('IMDb rating for all services')
chart  = sns.barplot(df['IMDb'].value_counts().index,y=df['IMDb'].value_counts())
chart.bar_label(chart.containers[0])
plt.show()
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Count Runtimes of movies
Runtime_df =pd.DataFrame( dict(df['Runtime'].value_counts().sort_values(ascending=False)[:10]).items(),columns=['Runtime','Count'])
Runtime_df
# Out:
#      Runtime  Count
# 0       90.0    971
# 1       95.0    489
# 2       92.0    434
# 3       93.0    422
# 4       85.0    408
# ..       ...    ...
# 152     19.0      8
# 153     32.0      8
# 154      9.0      8
# 155      7.0      8
# 156     10.0      8
#
# [157 rows x 2 columns]

# %%
plt.figure(figsize=(45,15))
plt.title('Runtime for all services')
chart  = sns.barplot(df['Runtime'].value_counts().index,y=df['Runtime'].value_counts())
chart.bar_label(chart.containers[0])
plt.show()
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Count number of movies for each director

df['Directors'] # for some movies more than director
# Out:
# 0                     Christopher Nolan
# 1        Lana Wachowski,Lilly Wachowski
# 2               Anthony Russo,Joe Russo
# 3                       Robert Zemeckis
# 4                          Sergio Leone
#                       ...
# 16739                      Bruce Bilson
# 16740                       Neal Israel
# 16741                      Neil Gelinas
# 16742              Richard Slater-Jones
# 16743                       James Algar
# Name: Directors, Length: 16744, dtype: object

# %%
#remove messing values
from collections import Counter
import operator
new_df = df[df['Directors']!=np.nan]

direc = list(new_df['Directors'])

flattened = [char for entry in direc for char in str(entry).split(',')]
D3 = dict(Counter(flattened))
#sorted(fla, key=D3.get, reverse=True)
D3.pop('nan')
dic = dict(sorted(D3.items(), key=operator.itemgetter(1), reverse=True)[:5])
dic
# Out:
# {'Jay Chapman': 36,
#  'Joseph Kane': 31,
#  'Cheh Chang': 29,
#  'Jim Wynorski': 23,
#  'William Beaudine': 23}

# %%
plt.figure(figsize=(10,8))
plt.title('Top 5 Directors ')
sns.barplot(x=list(dic.keys()),y=list(dic.values()))
# Out:
# <AxesSubplot:title={'center':'Top 5 Directors '}>

# %%
df[df['Directors']=='Jay Chapman'][['Directors','Title','IMDb','Runtime','Genres']]
# Out:
#          Directors                                           Title  IMDb  \
# 1014   Jay Chapman                          Jim Gaffigan: Obsessed   7.6
# 1234   Jay Chapman                     Iliza Shlesinger: War Paint   6.7
# 1417   Jay Chapman                   Tom Segura: Completely Normal   7.8
# 2211   Jay Chapman                         Todd Barry: Spicy Honey   6.7
# 2331   Jay Chapman                    Craig Ferguson: Tickle Fight   6.6
# 2393   Jay Chapman                   Colin Quinn: Unconstitutional   7.1
# 2447   Jay Chapman                        Lucas Brothers: On Drugs   5.5
# 2523   Jay Chapman                        D.L. Hughley: Contrarian   6.5
# 2636   Jay Chapman                             D.L. Hughley: Clear   6.7
# 2721   Jay Chapman                   Moshe Kasher: Live in Oakland   6.8
# 2859   Jay Chapman                     Todd Glass Stand-Up Special   6.1
# 3041   Jay Chapman                     Brad Paisley's Comedy Rodeo   5.5
# ...

# %%
#Explore Genres of movies
new_df = df[df['Genres']!=np.nan]

direc = list(new_df['Genres'])

flattened = [char for entry in direc for char in str(entry).split(',')]
D3 = dict(Counter(flattened))
D3.pop('nan')

dic = dict(sorted(D3.items(), key=operator.itemgetter(1), reverse=True)[:10])
dic
# Out:
# {'Drama': 7227,
#  'Comedy': 4637,
#  'Thriller': 3354,
#  'Action': 2683,
#  'Documentary': 2546,
#  'Romance': 2359,
#  'Horror': 2201,
#  'Crime': 1833,
#  'Adventure': 1778,
#  'Family': 1514}

# %%
plt.figure(figsize=(20,8))
plt.title('Top 10 Genres')
sns.barplot(x=list(dic.keys()),y=list(dic.values()))
# Out:
# <AxesSubplot:title={'center':'Top 10 Genres'}>

# %%
#Netflix top movies
top_netflix = netflix_df[netflix_df['IMDb']>8.5][['Title','IMDb']]
top_net = top_netflix.sort_values(ascending=False,by='IMDb').head(10)

# %%
plt.figure(figsize=(20,8))
plt.title('Top 10 movies in Netflix')
sns.barplot(x=top_net['Title'],y=top_net['IMDb'])
# Out:
# <AxesSubplot:title={'center':'Top 10 movies in Netflix'}, xlabel='Title', ylabel='IMDb'>

# %% [markdown]
# # Data cleaning

# %%
# checking missing values
df.isnull().sum()
# Out:
# Title                  0
# Year                   0
# Age                 9390
# IMDb                 571
# Rotten Tomatoes    11586
# Netflix                0
# Hulu                   0
# Prime Video            0
# Disney+                0
# Type                   0
# Directors            726
# Genres               275
# Country              435
# Language             599
# Runtime              592
# NewAge             10233
# Rot_Toma           11586
# dtype: int64

# %%
#most repeated country

df['Country'].mode()
# Out:
# 0    United States
# Name: Country, dtype: object

# %%
#replace rows with missing value for country,rating  with most repeated country
df['Country'].fillna(df['Country'].mode()[0],inplace=True)

# %%
df['Language'].fillna(df['Language'].value_counts().index[0], inplace=True)

# %%
df['Runtime'].fillna(df['Runtime'].value_counts().index[0], inplace=True)

# %%
# 9390 Age values and 11586 Rotten Tomatoes values are missing we can't do anything for missing values so we are dropping it
df.drop(columns={'Age','Rotten Tomatoes', 'NewAge', 'Rot_Toma'}, inplace=True)

# %%
#Taking dataframe from those in which values are present in it

df=df[df['Genres'].notna()]

# %%
df['IMDb'].fillna(df['IMDb'].value_counts().index[0], inplace=True)

# %%
df.drop(columns={'Directors'}, inplace=True)

# %%
df.isnull().sum()
# Out:
# Title          0
# Year           0
# IMDb           0
# Netflix        0
# Hulu           0
# Prime Video    0
# Disney+        0
# Type           0
# Genres         0
# Country        0
# Language       0
# Runtime        0
# dtype: int64

# %%
#check if there is some wrong values in some columns 
df['Type'].unique() #==> only 0 : drop it
# Out:
# array([0], dtype=int64)

# %%
df.drop(columns={'Type'}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16469 entries, 0 to 16743
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        16469 non-null  object
#  1   Year         16469 non-null  int64
#  2   IMDb         16469 non-null  float64
#  3   Netflix      16469 non-null  int64
#  4   Hulu         16469 non-null  int64
#  5   Prime Video  16469 non-null  int64
#  6   Disney+      16469 non-null  int64
#  7   Genres       16469 non-null  object
#  8   Country      16469 non-null  object
#  9   Language     16469 non-null  object
#  10  Runtime      16469 non-null  float64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 1.5+ MB

# %%
df.duplicated().sum() #no duplicated rows
# Out:
# 0

# %%
df['Title'].duplicated().sum()
# Out:
# 0
